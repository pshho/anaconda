# %%
import urllib.request

# 네이버API 서비스(ID/비밀번호) 등록
client_id = 'Gr3DZKpSitjNw83linRK'
client_secret = 'CM1z5bCrQ6'

encText = urllib.request.quote('파이썬')
# print(encText)
url = 'https://openapi.naver.com/v1/search/blog.json?query=' + encText
# print(url)

request = urllib.request.Request(url) # url 주소를 요청(호출)
request.add_header('X-Naver-Client-Id', client_id) # header로 id/비번 보내줌
request.add_header('X-Naver-Client-Secret', client_secret)

# 응답
response = urllib.request.urlopen(request) # requests.get(url)와 유사
print(response.getcode()) # 상태코드
print(type(response))
response.read().decode('utf-8')
# Out:
# 200
# <class 'http.client.HTTPResponse'>
# ...

# %%
import urllib.request
import json
import pandas as pd

def create_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = '/' + api_node + '.json'
    param_query = '?query=' + urllib.parse.quote(search_text)
    param_start = '&start=' + str(start_num)
    param_disp = '&display=' + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

url = create_url('book', '자바', 1, 11)

client_id = 'Gr3DZKpSitjNw83linRK'
client_secret = 'CM1z5bCrQ6'

request = urllib.request.Request(url)
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)

# 응답
response = urllib.request.urlopen(request)
result = json.loads(response.read().decode('utf-8'))
print(result)
# Out:
# {'lastBuildDate': 'Fri, 12 May 2023 16:40:50 +0900', 'total': 523, 'start': 1, 'display': 11, 'items': [{'title': '스프링 부트 3 백엔드 개발자 되기 : 자바 편 (JPA + OAuth2 + JWT + AWS와 배우는 스프링 부트 3 자바 백엔드 입문자를 위한 풀 패키지(연습문제 수록))', 'link': 'https://search.shopping.naver.com/book/catalog/39656965624', 'image': 'https://shopping-phinf.pstatic.net/main_3965696/39656965624.20230511071103.jpg', 'author': '신선영', 'discount': '27000', 'publisher': '골든래빗(주)', 'pubdate': '20230512', 'isbn': '9791191905298', 'description': '★ 자바 백엔드 개발자가 되고 싶다면\n★ 자바 언어 입문 그다음에 꼭 보세요실력을 갖춘 개발자로 성장하려면 시작이 중요합니다. 그래서 이 책은 무엇부터 익혀야 하는지 막막한 입문자에게 백엔드 개발의 필수 지식을 학습 로드맵 중심으로 설명합니다. 이어서 스프링 부트 3 개발에 꼭 필요한 4대장인 JPA ORM, OAuth2 인증, AWS 배포, CI/CD를 최신 트렌드에 맞게 그리고 실무에 유용하게 알려줍니다. 모든 장 끝에는 연습문제가 수록되어 있어 배운 내용을 점검할 수 있습니다. 이 책이 여러분의 백엔드 개발자 여정에 든든한 나침반이 되어 줄 겁니다.\n\n \n〈되기〉 시리즈 소개\n〈되기〉 시리즈는 이름 그대로 IT 분야에서 성장하려는 여러분을 위해 준비한 책입니다. 엄선된 IT 기술들을 로드맵과 함께 제시하고, 실무 중심으로 공부할 수 있도록 안내합니다. 여러분이 해당 분야에서 실무자로 빠르게 성장할 수 있도록 지원하겠습니다.'}, {'title': 'Do it! 
# ...

# %%
print('제목 :', result['items'][0]['title'])
print('저자 :', result['items'][0]['author'])
# Out:
# 제목 : 스프링 부트 3 백엔드 개발자 되기 : 자바 편 (JPA + OAuth2 + JWT + AWS와 배우는 스프링 부트 3 자바 백엔드 입문자를 위한 풀 패키지(연습문제 수록))
# 저자 : 신선영

# %%
# titles 생성
'''
for i in range(11):
    # print(result['items'][i]['title'])
    titles = result['items'][i]['title']
    authors = result['items'][i]['author']
    pubdates = result['items'][i]['pubdate']
'''

# 리스트 내포
titles = [result['items'][i]['title'] for i in range(11)]
authors = [result['items'][i]['author'] for i in range(11)]
pubdates = [result['items'][i]['pubdate'] for i in range(11)]

책 = pd.DataFrame({
    '책제목':titles,
    '작가':authors,
    '출판일':pubdates
})
책 = 책.set_index('책제목')
책
# Out:
#                                                                              작가  \
# 책제목
# 스프링 부트 3 백엔드 개발자 되기 : 자바 편 (JPA + OAuth2 + JWT ...                          신선영
# Do it! HTML+CSS+자바스크립트 웹 표준의 정석 (한 권으로 끝내는 웹 기본...                          고경희
# Do it! 알고리즘 코딩 테스트: 자바 편 (IT 기업 최신 출제 경향 완벽 분석!)                            김종관
# 코딩 개념 잡는 자바 코딩 문제집 (문제를 최대한 많이 풀어라!)                                   안겔 레오나르드
# 자바 (Seventh Edition)                                          Horstmann, Cay S.
# 모던 자바 인 액션 (람다, 스트림, 함수형, 리액티브 프로그래밍으로 새로워진 자바 ...  앨런 마이크로프트^마리오 푸스코^앨런 마이크로프트
# 한 입 크기로 잘라 먹는 리액트 (자바스크립트 기초부터 애플리케이션 배포까지)                                 이정환
# 자바 정복 (개정판)                                                                 김상형
# 자바사라사                                                                   다케다 린타로
# 자바시장                                                                        박계상
# 자바 ORM 표준 JPA 프로그래밍 (스프링 데이터 예제 프로젝트로 배우는 전자정부 ...                          김영한
#
# ...

# %%
import urllib.request
import json
import pandas as pd

def create_url(api_node, search_text, start_num, disp_num):
    base = "https://openapi.naver.com/v1/search"
    node = '/' + api_node + '.json'
    param_query = '?query=' + urllib.parse.quote(search_text)
    param_start = '&start=' + str(start_num)
    param_disp = '&display=' + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

url = create_url('book', '자바', 1, 11)

client_id = 'Gr3DZKpSitjNw83linRK'
client_secret = 'CM1z5bCrQ6'

request = urllib.request.Request(url)
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)

# 응답
response = urllib.request.urlopen(request)
result = json.loads(response.read().decode('utf-8'))
# print(result)

# 리스트 내포
titles = [result['items'][i]['title'] for i in range(11)]
authors = [result['items'][i]['author'] for i in range(11)]
pubdates = [result['items'][i]['pubdate'] for i in range(11)]

책 = pd.DataFrame({
    '책제목':titles,
    '작가':authors,
    '출판일':pubdates
})
책 = 책.set_index('책제목')
책.to_csv('./datas/book.csv', encoding='utf-8-sig')
책파일 = pd.read_csv('./datas/book.csv', index_col=0)
책파일
# Out:
#                                                                              작가  \
# 책제목
# 스프링 부트 3 백엔드 개발자 되기 : 자바 편 (JPA + OAuth2 + JWT ...                          신선영
# Do it! HTML+CSS+자바스크립트 웹 표준의 정석 (한 권으로 끝내는 웹 기본...                          고경희
# Do it! 알고리즘 코딩 테스트: 자바 편 (IT 기업 최신 출제 경향 완벽 분석!)                            김종관
# 코딩 개념 잡는 자바 코딩 문제집 (문제를 최대한 많이 풀어라!)                                   안겔 레오나르드
# 자바 (Seventh Edition)                                          Horstmann, Cay S.
# 모던 자바 인 액션 (람다, 스트림, 함수형, 리액티브 프로그래밍으로 새로워진 자바 ...  앨런 마이크로프트^마리오 푸스코^앨런 마이크로프트
# 한 입 크기로 잘라 먹는 리액트 (자바스크립트 기초부터 애플리케이션 배포까지)                                 이정환
# 자바 정복 (개정판)                                                                 김상형
# 자바사라사                                                                   다케다 린타로
# 자바시장                                                                        박계상
# 자바 ORM 표준 JPA 프로그래밍 (스프링 데이터 예제 프로젝트로 배우는 전자정부 ...                          김영한
#
# ...
